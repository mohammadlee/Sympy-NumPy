# %%
import numpy as np
import sympy as sy

# %%
A=sy.Matrix([[2,2,1],[1,1,1],[3,2,1]])
A
# Out:
# Matrix([
# [2, 2, 1],
# [1, 1, 1],
# [3, 2, 1]])

# %%
b=sy.Matrix([9,6,10 ])
b
# Out:
# Matrix([
# [ 9],
# [ 6],
# [10]])

# %%
A.solve(B)
# Out:
# Matrix([
# [1],
# [2],
# [3]])

# %%
a=sy.Symbol('a')
B=sy.Matrix([[1,a,2],[-1,2,2*a],[3,-1,-a]])
B
# Out:
# Matrix([
# [ 1,  a,   2],
# [-1,  2, 2*a],
# [ 3, -1,  -a]])

# %%
B.solve(b)
# Out:
# Matrix([
# [                     26/5],
# [(19*a - 56)/(5*a**2 - 10)],
# [(28*a - 19)/(5*a**2 - 10)]])

# %%
A.LUdecomposition()
# Out:
# (Matrix([
#  [  1, 0, 0],
#  [3/2, 1, 0],
#  [1/2, 0, 1]]),
#  Matrix([
#  [2,  2,    1],
#  [0, -1, -1/2],
#  [0,  0,  1/2]]),
#  [[1, 2]])

# %%
L,U,P=A.LUdecomposition()
P
# Out:
# [[1, 2]]

# %%
L
# Out:
# Matrix([
# [  1, 0, 0],
# [3/2, 1, 0],
# [1/2, 0, 1]])

# %%
U
# Out:
# Matrix([
# [2,  2,    1],
# [0, -1, -1/2],
# [0,  0,  1/2]])

# %%
L*U
# Out:
# Matrix([
# [2, 2, 1],
# [3, 2, 1],
# [1, 1, 1]])

# %%
A.LUsolve(b)
# Out:
# Matrix([
# [1],
# [2],
# [3]])

# %%
A=sy.randMatrix(3,3,0,4)
A
# Out:
# Matrix([
# [0, 4, 2],
# [2, 3, 2],
# [2, 4, 1]])

# %%
A=sy.randMatrix(10,10,0,6)
A
# Out:
# Matrix([
# [1, 6, 2, 2, 6, 1, 2, 2, 1, 3],
# [4, 4, 2, 0, 3, 3, 2, 0, 6, 6],
# [4, 2, 4, 4, 0, 4, 1, 3, 2, 4],
# [5, 1, 1, 2, 4, 4, 5, 5, 4, 0],
# [4, 0, 3, 3, 2, 1, 6, 1, 1, 0],
# [1, 6, 1, 4, 6, 4, 3, 2, 1, 0],
# [6, 0, 6, 5, 2, 5, 1, 0, 1, 4],
# [1, 6, 5, 1, 2, 6, 4, 4, 4, 1],
# [2, 2, 1, 6, 4, 2, 5, 3, 5, 4],
# [2, 4, 1, 4, 1, 6, 2, 4, 0, 5]])

# %%
B=sy.randMatrix(10,1,0,10)
B
# Out:
# Matrix([
# [8],
# [8],
# [5],
# [2],
# [6],
# [6],
# [1],
# [0],
# [7],
# [0]])

# %%
A.solve(B)
# Out:
# Matrix([
# [  8395714/4050797],
# [  9837129/4050797],
# [ -2349455/4050797],
# [  9964495/8101594],
# [ -8029755/8101594],
# [-17408799/8101594],
# [  -166327/4050797],
# [ -1843062/4050797],
# [  2398727/4050797],
# [ -3909321/8101594]])

# %%
A=sy.randMatrix(15,15,0,6)
B=sy.randMatrix(15,1,0,10)
A.solve(B)
# Out:
# Matrix([
# [ -1732101425/457031227],
# [-4324586297/1371093681],
# [   481504370/457031227],
# [ -1364926570/457031227],
# [ 3969600989/1371093681],
# [ 4261779514/1371093681],
# [    60509952/457031227],
# [ -446931898/1371093681],
# [  -247486397/457031227],
# [ -796789822/1371093681],
# [   911418452/457031227],
# [ 2289804157/1371093681],
# [   786602522/457031227],
# [  966238991/1371093681],
# [-2385632129/1371093681]])

# %%
A=sy.randMatrix(18,18,0,6)
B=sy.randMatrix(18,1,0,10)
A.solve(B)
# Out:
# Matrix([
# [ 15438639957151/29226894771042],
# [ -21070181701711/9742298257014],
# [ 44703618497071/29226894771042],
# [ 42245849329507/29226894771042],
# [  -3279075960575/4871149128507],
# [ -1200015596945/14613447385521],
# [ 32183692843897/29226894771042],
# [101403571607975/29226894771042],
# [-94562100424625/29226894771042],
# [-59293068288997/14613447385521],
# [ 73896533929001/29226894771042],
# [   5348201555756/4871149128507],
# [-42718734425201/14613447385521],
# [ 17776659112009/29226894771042],
# [-28671065045149/14613447385521],
# [    454988402699/1623716376169],
# [  -2264999195044/4871149128507],
# [128137453297157/29226894771042]])

# %%
A=sy.randMatrix(25,25,0,6)
B=sy.randMatrix(25,1,0,10)
A.LUsolve(B)
# Out:
# Matrix([
# [  -318341444714941594753/361021845769567791423],
# [  531275733687508754419/1083065537308703374269],
# [   124654570149160952783/361021845769567791423],
# [ 1982972635550111432576/1083065537308703374269],
# [   180188457475666330874/361021845769567791423],
# [ 2520283669997631874769/1083065537308703374269],
# [ -616408487011451402575/1083065537308703374269],
# [  -276287127427214328441/120340615256522597141],
# [   473986841959994303290/361021845769567791423],
# [ 2844826697092089383495/1083065537308703374269],
# [  209504340241652961518/1083065537308703374269],
# [  681723445320294457814/1083065537308703374269],
# [        -138760631309630171/987297663909483477],
# [-1135619665892746666030/1083065537308703374269],
# [  -458165475912346164931/361021845769567791423],
# [-2619188675188158240445/1083065537308703374269],
# [  871923259218480218945/1083065537308703374269],
# [-1385363302493607702023/1083065537308703374269],
# [ -855331037813078088304/1083065537308703374269],
# ...

# %%
A=sy.randMatrix(4,4,0,5)
A.LUdecomposition()
# Out:
# (Matrix([
#  [  1,   0,     0, 0],
#  [  0,   1,     0, 0],
#  [  2, 3/2,     1, 0],
#  [1/2,   1, -1/11, 1]]),
#  Matrix([
#  [2, 0,     3,     2],
#  [0, 2,     1,     3],
#  [0, 0, -11/2, -11/2],
#  [0, 0,     0,  -3/2]]),
#  [])

# %%
A.QRdecomposition()
# Out:
# (Matrix([
#  [2*sqrt(21)/21, -4*sqrt(69)/69,    99*sqrt(215418)/71806,   5*sqrt(1338)/446],
#  [            0,  2*sqrt(69)/23,     7*sqrt(215418)/30774, 25*sqrt(1338)/1338],
#  [4*sqrt(21)/21,    sqrt(69)/69, -109*sqrt(215418)/107709,    -sqrt(1338)/669],
#  [  sqrt(21)/21,  4*sqrt(69)/69,  139*sqrt(215418)/107709, -11*sqrt(1338)/669]]),
#  Matrix([
#  [sqrt(21), 2*sqrt(21)/3,   17*sqrt(21)/21,         19*sqrt(21)/21],
#  [       0,   sqrt(69)/3,    8*sqrt(69)/69,         25*sqrt(69)/69],
#  [       0,            0, sqrt(215418)/161, 307*sqrt(215418)/71806],
#  [       0,            0,                0,      11*sqrt(1338)/446]]))

# %%
Q,R=A.QRdecomposition()
Q
# Out:
# Matrix([
# [2*sqrt(21)/21, -4*sqrt(69)/69,    99*sqrt(215418)/71806,   5*sqrt(1338)/446],
# [            0,  2*sqrt(69)/23,     7*sqrt(215418)/30774, 25*sqrt(1338)/1338],
# [4*sqrt(21)/21,    sqrt(69)/69, -109*sqrt(215418)/107709,    -sqrt(1338)/669],
# [  sqrt(21)/21,  4*sqrt(69)/69,  139*sqrt(215418)/107709, -11*sqrt(1338)/669]])

# %%
R
# Out:
# Matrix([
# [sqrt(21), 2*sqrt(21)/3,   17*sqrt(21)/21,         19*sqrt(21)/21],
# [       0,   sqrt(69)/3,    8*sqrt(69)/69,         25*sqrt(69)/69],
# [       0,            0, sqrt(215418)/161, 307*sqrt(215418)/71806],
# [       0,            0,                0,      11*sqrt(1338)/446]])

# %%
A=sy.randMatrix(18,18,0,6)
B=sy.randMatrix(18,1,0,10)
A.QRsolve(B)
# Out:
# Matrix([
# [ 149362075282006/84981474384785],
# [  -7258383669728/16996294876957],
# [-121676251245063/84981474384785],
# [ -38061006000761/84981474384785],
# [  45871866110179/16996294876957],
# [ 151999680399848/84981474384785],
# [  25558880267213/16996294876957],
# [  19184716245657/16996294876957],
# [-408273078060682/84981474384785],
# [  73148248013293/84981474384785],
# [ -54304757800037/84981474384785],
# [ -28886788433564/16996294876957],
# [ -20920576915118/84981474384785],
# [ -40936389575231/84981474384785],
# [  69317305426321/16996294876957],
# [   8400077963183/84981474384785],
# [ -34094725322752/84981474384785],
# [ -41513654283323/16996294876957]])

# %%
A=sy.randMatrix(50,50,0,6)
B=sy.randMatrix(50,1,0,10)
A.QRsolve(B)
# Out:
# Matrix([
# [   -98641204890781933891747268712786490107777823510/639690669391067252832194964043487887315177730069],
# [ -236880836284409160289953829302376260142057628669/1279381338782134505664389928086975774630355460138],
# [ -260975482095369193026249569644341081147327287227/1279381338782134505664389928086975774630355460138],
# [  1091266295161063421110704597931856795395952305036/639690669391067252832194964043487887315177730069],
# [   387117294715763886105722564676715393498612005398/639690669391067252832194964043487887315177730069],
# [ -850821766771710484549142389284981138921936665993/1279381338782134505664389928086975774630355460138],
# [ 1827155686492241032443946623745923823534922019617/1279381338782134505664389928086975774630355460138],
# [     13129794413583010495445830634658564215793887554/22058298944519560442489481518740961631557852761],
# [  189743182618762193561347293392037122535903744373/1279381338782134505664389928086975774630355460138],
# ...
